# %% [markdown]
# <a href="https://colab.research.google.com/github/mmubashirdev/AI/blob/main/DataPreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.competition_download('titanic')

print("Path to competition files:", path)
# Out:
# ---------------------------------------------------------------------------
# UnauthenticatedError                      Traceback (most recent call last)
# /tmp/ipykernel_2245/1468315158.py in <cell line: 0>()
#       2
#       3 # Download latest version
# ----> 4 path = kagglehub.competition_download('titanic')
#       5
#       6 print("Path to competition files:", path)
#
# /usr/local/lib/python3.13/dist-packages/kagglehub/competition.py in competition_download(handle, path, force_download, output_dir)
#      28     h = parse_competition_handle(handle)
#      29     logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 30     path, _ = registry.competition_resolver(
#      31         h,
#      32         path,
#
# /usr/local/lib/python3.13/dist-packages/kagglehub/registry.py in __call__(self, *args, **kwargs)
#      26         for impl in reversed(self._impls):
#      27             if impl.is_supported(*args, **kwargs):
# ...

# %% [markdown]
# ### Authenticate with Kaggle
#
# To resolve the `UnauthenticatedError`, you need to provide your Kaggle API credentials. Here's how to do it:
#
# 1.  **Get your Kaggle API Token:**
#     *   Go to [Kaggle.com](https://www.kaggle.com/).
#     *   Log in to your account.
#     *   Click on your profile picture in the top right corner and select "My Account".
#     *   Scroll down to the "API" section and click "Create New API Token". This will download a `kaggle.json` file containing your username and key.
#
# 2.  **Add Credentials to Colab Secrets:**
#     *   In Colab, click the "🔑" (Secrets) icon in the left panel.
#     *   Add two new secrets:
#         *   **Name:** `KAGGLE_USERNAME`, **Value:** (Your username from `kaggle.json`)
#         *   **Name:** `KAGGLE_KEY`, **Value:** (Your API key from `kaggle.json`)
#     *   Ensure "Notebook access" is toggled on for both secrets.
#
# Once you've set up these secrets, run the following cell to load them as environment variables. Then, you can retry the `kagglehub.competition_download` call.

# %%
# Import os module to set environment variables
import os
# Import userdata from google.colab to access secrets
from google.colab import userdata

# Load Kaggle credentials from Colab secrets and set as environment variables
os.environ['KAGGLE_USERNAME'] = userdata.get('KAGGLE_USERNAME')
os.environ['KAGGLE_KEY'] = userdata.get('KAGGLE_KEY')

print("Kaggle credentials loaded from Colab secrets.")
print("You can now retry downloading the competition data.")
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2245/3040386137.py in <cell line: 0>()
#       5
#       6 # Load Kaggle credentials from Colab secrets and set as environment variables
# ----> 7 os.environ['KAGGLE_USERNAME'] = userdata.get('KAGGLE_USERNAME')
#       8 os.environ['KAGGLE_KEY'] = userdata.get('KAGGLE_KEY')
#       9
#
# /usr/local/lib/python3.13/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret KAGGLE_USERNAME does not exist.

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
data = {
    "Age": [22, 38, 26, 35, 35],
    "Gender": ['male', 'female', 'male', 'female', 'female'],
    "Marks": [85, 90, 92, 88, 95],
    "StudyHours": [4, 5, 6, 3, 4],
    "Passed": ["yes","no","no","yes","yes"]
}

df = pd.DataFrame(data)
print("Original Dataset")
print(df)
# Out:
# Original Dataset
#    Age  Gender  Marks  StudyHours Passed
# 0   22    male     85           4    yes
# 1   38  female     90           5     no
# 2   26    male     92           6     no
# 3   35  female     88           3    yes
# 4   35  female     95           4    yes

# %%
print("\nMissing values: ")
print(df.isnull().sum())
df["Age"]=df["Age"].fillna(df["Age"].mean())
# Out:
# Missing values:
# Age           0
# Gender        0
# Marks         0
# StudyHours    0
# Passed        0
# dtype: int64

# %%
df= df.drop_duplicates()

# %%
encoder = LabelEncoder()
df["Gender"] = encoder.fit_transform(df["Gender"])
df["Passed"] = encoder.fit_transform(df["Passed"])

# %%
print("\nAfter Preprocessing")
print(df)
# Out:
# After Preprocessing
#    Age  Gender  Marks  StudyHours  Passed
# 0   22       1     85           4       1
# 1   38       0     90           5       0
# 2   26       1     92           6       0
# 3   35       0     88           3       1
# 4   35       0     95           4       1
