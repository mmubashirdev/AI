# %% [markdown]
# <a href="https://colab.research.google.com/github/mmubashirdev/AI/blob/main/MLschool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy

x = numpy.random.uniform(0.0,0.5,250)

plt.hist(x,5)
plt.show()
