# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

if num1>num2:
  if num1>num3:
    print(f"{num1} is the largest")
  else:
    print(f"{num3} is the largest")
elif num2>num1:
  if num2>num3:
    print(f"{num2} is the largest number")
  else:
    print(f"{num3} is the largest")
# Out:
# 6 is the largest

# %%
n = int(input("Enter the day number"))

if n==1:
  print("Sunday")
elif n==2:
  print("Monday")
elif n==3:
  print("Tuesday")
elif n==4:
  print("Wednesday")
elif n==5:
  print("Thursday")
elif n==6:
  print("Friday")
elif n==7:
  print("Saturday")
# Out:
# Monday

# %%
n = int(input("Enter number of terms"))
a,b,i=0,1,0

print("Fibonacci series: ")
while i<n:
  print(a,end=" ")
  a,b = b,a+b
  i +=1
# Out:
# Fibonacci series:
# 0 1 1 2 3

# %%
def factorial(n):
  if n == 0 or n == 1:
    return 1
  else:
    return n*factorial(n-1)

num = int(input("Enter a number"))
print(f"The factorial of {num} is :",factorial(num))
# Out:
# The factorial of 5 is : 120

# %%
import math

a = float(input("Enter side a: "))
b = float(input("Enter side b: "))
c = float(input("Enter side c: "))

s = (a+b+c)/2

area = math.sqrt(s*(s-a)*(s-b)*(s-c))

print("Area of Triangle :",area)
# Out:
# Area of Triangle : 43.30127018922193

# %%
import math

base = float(input("Enter base: "))
perpendicular = float(input("Enter perpendicular"))

hypotenuse = math.sqrt(base**2 + perpendicular**2)

print('hypotenuse: ',hypotenuse)
# Out:
# hypotenuse:  7.0710678118654755

# %%
def calculate_marks(marks):
  if marks>=90:
    return "A"
  elif marks >= 70:
    return "B"
  elif marks >= 60:
    return "C"
  elif marks >= 50:
    return "D"
  else:
    return "F"
  
  
students = [("Mubashir",80),("Ali",90),("Ahmed",70),("Omer",75),("Json",30)]

for name,marks in students:
  grade = calculate_marks(marks)
  print(f"Student: {name}, Marks: {marks}, Grade: {grade}")
  
def count_passed(stud):
  passed = 0
  for _,marks in stud:
    if marks>=50:
      passed+=1
  return passed
  
print("Total Students: ",len(students))
print("Students passed: ",count_passed(students))
print("Student Failed: ",len(students)-count_passed(students))
# Out:
# Student: Mubashir, Marks: 80, Grade: B
# Student: Ali, Marks: 90, Grade: A
# Student: Ahmed, Marks: 70, Grade: B
# Student: Omer, Marks: 75, Grade: B
# Student: Json, Marks: 30, Grade: F
# Total Students:  5
# Students passed:  4
# Student Failed:  1

# %%
def count_vowels(txt):
  vowels = "aeiouAEIOU"
  count = 0
  for char in txt:
   if char in vowels:
     count +=1
  return count

sentence = "Hello World!"
print("Number of Vowels in sentence are: ",count_vowels(sentence))
# Out:
# Number of Vowels in sentence are:  3
